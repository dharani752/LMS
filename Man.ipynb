# %%
class Manager:
    d={}
    details={}
    Transaction={}
    def __init__(self):
        self.d={}
        self.details={}
        self.Transaction={}
    def login(self,email,password):
        if email in self.details:
            if self.details[email]==password:
                print("you are sucessfully login")
            else:
                print("please enter the correct password")
        else:
            print("please enter the correct details")
    def sigin(self,email,password):
        if "gmail.com" in email and len(password)>=5 and len(password)<=20:
            self.details[email]=password
            print("welcome")
        else:
            print("please  try again with gmail account")
            print("length of password must 5 to 20")
    def Addbook(self,book):
        if book in self.d:
            self.d[book]+=1
        else:
            self.d[book]=1
    def remove_book(self,book):
        if book in self.d and self.d[book]!=0:
            self.d[book]-=1
        else:
            print("Sorry, Book is not avaliable")
    def Accept_payment(self,UPI):
        if UPI in self.Transaction:
            print("accept  the payment")
        else:
            print("Transcations are not accept")
        
    def view_books(self):
        return self.d
        
    
            
M=Manager()
M.d={}
while 1:
    print("1.sigin")
    print("2.login")
    print("3 Add book")
    print("4. Remove book")
    print("5.view_book")
    print("6.Accept_payment")
    k=int(input())
    if k==1:
        email=input("please enter your email:")
        password=input("pleae enter your password")
        M.sigin(email,password)
    elif k==2:
        email=input("please enter your email:")
        password=input("pleae enter your password")
        M.login(email,password)
    elif k==3:
        book=input("enter the nameof the book which you want to add")
        M.Addbook(book)
    elif k==4:
        book=input("enter the name of the book which you want to remove")
        M.remove_book(book)
    elif k==5:
        r=M.view_books()
        print(r)
    elif k==6:
        UPI=input("enter UPI id of customer")
        M.Accept_payment(UPI)
    else:
        break
# Out:
# 1.sigin
# 2.login
# 3 Add book
# 4. Remove book
# 5.view_book
# 6.Accept_payment
# 3
# enter the nameof the book which you want to addC
# 1.sigin
# 2.login
# 3 Add book
# 4. Remove book
# 5.view_book
# 6.Accept_payment
# 3
# enter the nameof the book which you want to addC
# 1.sigin
# 2.login
# 3 Add book
# 4. Remove book
# 5.view_book
# 6.Accept_payment
# 5
# {'C': 2}
# 1.sigin
# 2.login
# 3 Add book
# 4. Remove book
# 5.view_book
# 6.Accept_payment
# 7

# %%
from datetime import date,timedelta

today = date.today()
class Customer():
    ts=[]
    c=0
    def __init__(self,name):
        self.ts=[]
        self.c=0
        self.book_det={}
    def login(self,email,password):
        if email in self.details:
            if self.details[email]==password:
                print("you are sucessfully login")
            else:
                print("please enter the correct password")
        else:
            print("please enter the correct details")
    def sigin(self,email,password):
        if "gmail.com" in email and len(password)>=5 and len(password)<=20:
            self.details[email]=password
            print("welcome")
        else:
            print("please  try again with gmail account")
            print("length of password must 5 to 20")
    def view_book(self):
        ki=M.view_books()
        print(ki)
    def check_book(self,book_name):
        k=M.view_books()
        if book_name in k and k[book_name]!=0:
            self.c=1
            print("Book is avaliable")
        else:
            print("Sorry, Book is not avaliable")
        return self.c 
    def rent_book(self,book_name):
        k=self.check_book(book_name)
        if k!=0:
            self.book_det[name]=[book_name,date.today().isoformat(),(date.today()+timedelta(days=30)).isoformat()]
        else:
            print("Sorry, Book is not avaliable")
        
    def pay_bill(self,name):
        print(self.book_det)
        if name in self.book_det:
            if self.book_det[name][2]<date.today().isoformat():
                print("one time only one book payment is acceptable")
                print("Pay the amonut of 100 for each book")
                t=input("enter your transcation id")
                self.ts.append(t)
            else:
                print("No fine")
        else:
            print("sorry")        
        
name=input("please enter your name:")       
r=Customer(name)

while 1:
    print("1.sigin")
    print("2.login")
    print("3.view_book")
    print("4.Check book")
    print("5.rent a book")
    k=int(input())
    if k==1:
        email=input("please enter your email:")
        password=input("pleae enter your password")
        r.sigin(email,password)
    elif k==2:
        email=input("please enter your email:")
        password=input("pleae enter your password")
        r.login(email,password)
    elif k==3:
        r.view_book()
    elif k==4:
        print("enter the book that u want to check")
        book_name=input("name of the book:")
        r.check_book(book_name)
    elif k==5:
        print("enter the book that u want to rent")
        book_name=input("name of the book:")
        r.rent_book(book_name)
    elif k==6:
        r.pay_bill(name)
        
    
    
    else:
        break
# Out:
# please enter your name:dharani
# 1.sigin
# 2.login
# 3.view_book
# 4.Check book
# 5.rent a book
# 5
# enter the book that u want to rent
# name of the book:C
# Book is avaliable
# 1.sigin
# 2.login
# 3.view_book
# 4.Check book
# 5.rent a book
# 6
# {'dharani': ['C', '2023-05-13', '2023-06-12']}
# No fine
# 1.sigin
# 2.login
# 3.view_book
# 4.Check book
# 5.rent a book
# 0
